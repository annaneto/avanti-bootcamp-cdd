# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/atlantico-academy/datasets/main/diamonds.csv")
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.to_csv("../data/raw/data.csv", index=False)

# %%
dicionario = pd.DataFrame([
    {
        "variavel" : "price",
        "descrição" : "preço em USD",
        "tipo" : "quantitativa",
        "subtipo" : "contínua",
    },
    {
        "variavel" : "carat",
        "descrição" : "peso do diamante",
        "tipo" : "quantitativa",
        "subtipo" : "contínua",
    },
     {
        "variavel" : "cut",
        "descrição" : "qualidade do corte",
        "tipo" : "qualitativa",
        "subtipo" : "ordinal",
    },
    {
        "variavel" : "color",
        "descrição" : "cor do diamante ",
        "tipo" : "qualitativa",
        "subtipo" : "ordinal",
    },
    {
        "variavel" : "clarity",
        "descrição" : "uma medida de quão claro é o diamante",
        "tipo" : "qualitativa",
        "subtipo " : "ordinal",
    },
     {
        "variavel" : "x",
        "descrição" : "comprimento em milímetro",
        "tipo" : "quantitativa",
        "subtipo" : "contínua",
    },
    {
        "variavel" : "y",
        "descrição" : "largura em milímetro",
        "tipo" : "quantitativa",
        "subtipo" : "contínua",
    },
    {
        "variavel" : "z",
        "descrição" : "profundidade em milímetro",
        "tipo" : "quantitativa",
        "subtipo" : "contínua",
    },
    {
        "variavel" : "depth",
        "descrição" : "porcentagem total de profundidade",
        "tipo" : "quantitativa",
        "subtipo" : "contínua",
    },
    {
        "variavel" : "table",
        "descrição" : "largura do topo do diamante em relação ao ponto mais largo",
        "tipo" : "quantitativa",
        "subtipo" : "contínua",
    }
])
dicionario.to_csv("../data/external/dictionary.csv", index=False)
dicionario
# Out:
#   variavel                                          descrição          tipo  \
# 0    price                                       preço em USD  quantitativa
# 1    carat                                   peso do diamante  quantitativa
# 2      cut                                 qualidade do corte   qualitativa
# 3    color                                   cor do diamante    qualitativa
# 4  clarity              uma medida de quão claro é o diamante   qualitativa
# 5        x                           comprimento em milímetro  quantitativa
# 6        y                               largura em milímetro  quantitativa
# 7        z                          profundidade em milímetro  quantitativa
# 8    depth                  porcentagem total de profundidade  quantitativa
# 9    table  largura do topo do diamante em relação ao pont...  quantitativa
#
#     subtipo
# 0  contínua
# 1  contínua
# 2   ordinal
# 3   ordinal
# 4   ordinal
# 5  contínua
# 6  contínua
# 7  contínua
# 8  contínua
# 9  contínua
