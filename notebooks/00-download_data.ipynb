# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/atlantico-academy/datasets/main/diamonds.csv")
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.to_csv("../data/raw/data.csv", index=False)

# %%
dicionario = pd.DataFrame([
    {
        "variável" : "Preço",
        "descrição" : "Preço em USD",
        "tipo" : "Quantitativa",
        "subtipo" : "Contínua",
    },
    {
        "variável" : "Quilate",
        "descrição" : "Peso do diamante",
        "tipo" : "Quantitativa",
        "subtipo" : "Contínua",
    },
     {
        "variável" : "Corte",
        "descrição" : "Qualidade do corte",
        "tipo" : "Qualitativa",
        "subtipo" : "Ordinal",
    },
    {
        "variável" : "Cor",
        "descrição" : "Cor do diamante ",
        "tipo" : "Qualitativa",
        "subtipo" : "Ordinal",
    },
    {
        "variável" : "Clareza",
        "descrição" : "Uma medida de quão claro é o diamante",
        "tipo" : "Qualitativa",
        "subtipo" : "Ordinal",
    },
     {
        "variável" : "x",
        "descrição" : "Comprimento em milímetro",
        "tipo" : "Quantitativa",
        "subtipo" : "Contínua",
    },
    {
        "variável" : "y",
        "descrição" : "Largura em milímetro",
        "tipo" : "Quantitativa",
        "subtipo" : "Contínua",
    },
    {
        "variável" : "z",
        "descrição" : "Profundidade em milímetro",
        "tipo" : "Quantitativa",
        "subtipo" : "Contínua",
    },
    {
        "variável" : "Profundidade",
        "descrição" : "Porcentagem total de profundidade",
        "tipo" : "Quantitativa",
        "subtipo" : "Contínua",
    },
    {
        "variável" : "Mesa",
        "descrição" : "Largura do topo do diamante em relação ao ponto mais largo",
        "tipo" : "Quantitativa",
        "subtipo" : "Contínua",
    }
])
dicionario.to_csv("../data/external/dictionary.csv", index=False)
dicionario
# Out:
#        variável                                          descrição  \
# 0         Preço                                       Preço em USD
# 1       Quilate                                   Peso do diamante
# 2         Corte                                 Qualidade do corte
# 3           Cor                                   Cor do diamante
# 4       Clareza              Uma medida de quão claro é o diamante
# 5             x                           Comprimento em milímetro
# 6             y                               Largura em milímetro
# 7             z                          Profundidade em milímetro
# 8  Profundidade                  Porcentagem total de profundidade
# 9          Mesa  Largura do topo do diamante em relação ao pont...
#
#            tipo   subtipo
# 0  Quantitativa  Contínua
# 1  Quantitativa  Contínua
# 2   Qualitativa   Ordinal
# 3   Qualitativa   Ordinal
# 4   Qualitativa   Ordinal
# 5  Quantitativa  Contínua
# 6  Quantitativa  Contínua
# ...
